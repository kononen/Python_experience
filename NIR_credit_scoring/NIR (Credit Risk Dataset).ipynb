# %%
#import sklearn
import numpy as np
import matplotlib.pyplot as plt
#from sklearn import datasets, manifold
#from sklearn.cluster import KMeans
#from sklearn import decomposition
import pandas as pd
#import seaborn as sns 
#import math


ds = pd.read_csv('/Users/rust/Documents/Мага/НИР/credit_risk_dataset.csv')

#ds = ds[]

display(ds)
display('person_home_ownership' , ds['person_home_ownership'].unique())
display('loan_intent' , ds['loan_intent'].unique())
display('loan_grade' , ds['loan_grade'].unique())
display('cb_person_default_on_file' , ds['cb_person_default_on_file'].unique())

display('person_emp_length' , ds['person_emp_length'].unique())
display('person_age' , ds['person_age'].unique())

display(ds.loc[ds['person_emp_length'] == 123])
plt.scatter(ds['person_emp_length'],ds['person_age'])
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
ds[['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file']] = ds[['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file']].apply(lambda x: pd.factorize(x)[0])
#display(ds)

ds = ds[ds['person_age'] < 100] 
ds = ds[ds['person_emp_length'] < 100] 


print("============================")

display(ds)

#l_null_rows = 
len(ds)

#null1 = ds.count(None)
number_all_rows = len(ds.axes[0])

display('person_emp_length' , ds['person_emp_length'].unique())
display('person_age' , ds['person_age'].unique())
display('person_home_ownership' , ds['person_home_ownership'].unique())


ds=ds.dropna()




#ds= ds.drop(ds.columns[10],axis = 1)

display('colums =', len(ds.columns))
number_without_null_rows = len(ds.axes[0])

null2 = number_all_rows - number_without_null_rows
display('number none rows  topor = ' , null2)
#display('number none rows1 smart = ' , null1)



ds.to_excel("output.xlsx")
# Out:
# ...
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 1              21           9600                      1                5.0
# 2              25           9600                      2                1.0
# 3              23          65500                      0                4.0
# 4              24          54400                      0                8.0
# 5              21           9900                      1                2.0
# ...           ...            ...                    ...                ...
# 32576          57          53000                      2                1.0
# 32577          54         120000                      2                4.0
# 32578          65          76000                      0                3.0
# 32579          56         150000                      2                5.0
# 32580          66          42000                      0                2.0
#
# ...

# %%
ds = ds[ds['person_age'] > 18] 

display(ds)
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 1              21           9600                      1                5.0
# 2              25           9600                      2                1.0
# 3              23          65500                      0                4.0
# 4              24          54400                      0                8.0
# 5              21           9900                      1                2.0
# ...           ...            ...                    ...                ...
# 32576          57          53000                      2                1.0
# 32577          54         120000                      2                4.0
# 32578          65          76000                      0                3.0
# 32579          56         150000                      2                5.0
# 32580          66          42000                      0                2.0
#
# ...

# %%
plt.scatter(ds['person_emp_length'],ds['person_age'])
