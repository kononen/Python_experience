# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import sklearn
import random
from sklearn.datasets import make_blobs 
from sklearn.cluster import KMeans
from sklearn import tree #убрать потом 
from sklearn.datasets import load_iris #убрать потом 
import pandas as pd



np.random.seed(0)
n_samples = 150 #Количество точек
random_state = 3
k=2 #Количество кластеров
n=100
dim=2

# Вариант 5

centers = [(0.2, 5), (1, 5)] #Центры кластеров
blobs = make_blobs(n_samples=n_samples,
                             centers=centers,
                             cluster_std=[(0.1, 0.5), (0.09, 0.5)],
                             random_state=random_state)
bl = blobs[0] 
plt.scatter(bl[:, 0], bl[:, 1], marker='o')



#iris = load_iris()
#X,Y = bl,blobs[1]   
#classif = tree.DecisionTreeClassifier(criterion = 'entropy')
#classif = classif.fit(X,Y)
#tree.plot_tree(classif)

ds = pd.read_csv('/Users/rust/Documents/Мага/МЛ/drug200.csv')
ds[['Sex','BP','Cholesterol','Drug']] = ds[['Sex','BP','Cholesterol','Drug']].apply(lambda x: pd.factorize(x)[0])

display(ds[['Age','Sex','BP','Cholesterol','Na_to_K']])

#Задаём данные и метки 
X = ds[['Age','Sex','BP','Cholesterol','Na_to_K']]
Y = ds[['Drug']]

classif = tree.DecisionTreeClassifier(criterion = 'entropy')
classif = classif.fit(X,Y)
tree.plot_tree(classif)

#display(classif)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 0     23    0   0            0   25.355
# 1     47    1   1            0   13.093
# 2     47    1   1            0   10.114
# 3     28    0   2            0    7.798
# 4     61    0   1            0   18.043
# ..   ...  ...  ..          ...      ...
# 195   56    0   1            0   11.567
# 196   16    1   1            0   12.006
# 197   52    1   2            0    9.894
# 198   23    1   2            1   14.020
# 199   40    0   1            1   11.349
#
# [200 rows x 5 columns]
# [Text(0.625, 0.9, 'x[4] <= 14.829\nentropy = 1.969\nsamples = 200\nvalue = [91, 16, 54, 23, 16]'),
#  Text(0.5, 0.7, 'x[2] <= 0.5\nentropy = 1.788\nsamples = 109\nvalue = [0, 16, 54, 23, 16]'),
#  Text(0.25, 0.5, 'x[0] <= 50.5\nentropy = 0.977\nsamples = 39\nvalue = [0, 0, 0, 23, 16]'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23, 0]'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 16]'),
# ...

# %%
classif.score(X,Y)
# Out:
# 1.0
